# %%
from src.mlflow_utils import setup_mlflow
import mlflow

setup_mlflow("air-paradis")

with mlflow.start_run(run_name="smoke-test"):
    mlflow.log_param("test", 1)
    mlflow.log_metric("accuracy", 0.5)

print("Smoke test OK ✅")
# Out:
# 2025/12/19 15:01:31 INFO mlflow.tracking.fluent: Experiment with name 'air-paradis' does not exist. Creating a new experiment.
# Smoke test OK ✅
